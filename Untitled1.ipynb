# %% [markdown]
# <a href="https://colab.research.google.com/github/ShilviaIrani/202255202004-Shilvia/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from google.colab import drive
# drive.mount ('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix


import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_excel("drive/MyDrive/Shilvia/TM9/dataset/DatasetMamikosMachineLearning.xlsx")

# %%
data.head()
# Out:
#                                                 nama    harga  rating   jenis  \
# 0        Kost Apik Aisyah Kukusan Tipe A  Beji Depok  1143000     NaN   Putri
# 1    Kost Apik UI Puspita  Tipe A Kukusan Beji Depok  1323000     NaN   Putri
# 2  Kost Singgahsini Alhidayah EMH-4 Tipe A  Beji ...  1683000     NaN   Putri
# 3    Kost Apik Duta Residence Tipe A Sukmajaya Depok  1548000     NaN  Campur
# 4    Kost Apik UI Puspita  Tipe B Kukusan Beji Depok  1233000     NaN   Putri
#
#   Kamar Mandi Dalam  Wifi  AC Kloset Duduk  Kasur
# 0               KMD   NaN  AC          NaN  Kasur
# 1               KMD  WiFi  AC          NaN  Kasur
# 2               KMD  WiFi  AC           KD  Kasur
# 3               KMD  WiFi  AC           KD  Kasur
# 4               KMD  WiFi  AC          NaN  Kasur

# %%
data.tail()
# Out:
#                                                     nama    harga  rating  \
# 10995          Kost Va Tipe A1 Jagakarsa Jakarta Selatan   700000     NaN
# 10996               Kost Pondok Katama Tipe B Beji Depok   900000     NaN
# 10997                       Kost Wisma Violet Beji Depok   800000     NaN
# 10998  Kost Eksklusif Mara Juara Tipe Large Bedroom B...  2499000     NaN
# 10999       Kost Giyan Exclusive Tipe Reguler Beji Depok  1100000     NaN
#
#         jenis Kamar Mandi Dalam  Wifi   AC Kloset Duduk  Kasur
# 10995   Putra               NaN  WiFi  NaN           KD  Kasur
# 10996   Putra               NaN  WiFi  NaN          NaN  Kasur
# 10997   Putri               KMD  WiFi  NaN          NaN    NaN
# 10998  Campur               KMD  WiFi   AC           KD  Kasur
# 10999  Campur               KMD   NaN   AC           KD    NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   nama               11000 non-null  object
#  1   harga              11000 non-null  int64
#  2   rating             2786 non-null   float64
#  3   jenis              11000 non-null  object
#  4   Kamar Mandi Dalam  9976 non-null   object
#  5   Wifi               8118 non-null   object
#  6   AC                 5816 non-null   object
#  7   Kloset Duduk       7182 non-null   object
#  8   Kasur              10702 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 773.6+ KB

# %%
data.shape
# Out:
# (11000, 9)

# %%
data.isnull().sum()
# Out:
# nama                    0
# harga                   0
# rating               8214
# jenis                   0
# Kamar Mandi Dalam    1024
# Wifi                 2882
# AC                   5184
# Kloset Duduk         3818
# Kasur                 298
# dtype: int64

# %%
data.fillna('0',axis=0,inplace=True)

# %%
data.dtypes
# Out:
# nama                 object
# harga                 int64
# rating               object
# jenis                object
# Kamar Mandi Dalam    object
# Wifi                 object
# AC                   object
# Kloset Duduk         object
# Kasur                object
# dtype: object

# %%
import missingno as msno
msno.bar(data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.isnull().sum()
# Out:
# nama                 0
# harga                0
# rating               0
# jenis                0
# Kamar Mandi Dalam    0
# Wifi                 0
# AC                   0
# Kloset Duduk         0
# Kasur                0
# dtype: int64

# %%
data.head(10)
# Out:
#                                                 nama    harga rating   jenis  \
# 0        Kost Apik Aisyah Kukusan Tipe A  Beji Depok  1143000      0   Putri
# 1    Kost Apik UI Puspita  Tipe A Kukusan Beji Depok  1323000      0   Putri
# 2  Kost Singgahsini Alhidayah EMH-4 Tipe A  Beji ...  1683000      0   Putri
# 3    Kost Apik Duta Residence Tipe A Sukmajaya Depok  1548000      0  Campur
# 4    Kost Apik UI Puspita  Tipe B Kukusan Beji Depok  1233000      0   Putri
# 5    Kost Apik Duta Residence Tipe B Sukmajaya Depok  1008000   50.0  Campur
# 6          Kost Apik Griya Osfa UI Tipe A Beji Depok  1368000      0   Putri
# 7             Kost Apik Wisma Okki Tipe B Beji Depok  1008000   47.0   Putri
# 8  Kost Singgahsini Alhidayah EMH-4 Tipe B  Beji ...  1249500      0   Putri
# 9        Kost Apik The Cozy Dorms Kukusan Beji Depok  1278000      0  Campur
#
#   Kamar Mandi Dalam  Wifi  AC Kloset Duduk  Kasur
# 0               KMD     0  AC            0  Kasur
# 1               KMD  WiFi  AC            0  Kasur
# 2               KMD  WiFi  AC           KD  Kasur
# 3               KMD  WiFi  AC           KD  Kasur
# 4               KMD  WiFi  AC            0  Kasur
# 5               KMD  WiFi   0            0  Kasur
# 6               KMD  WiFi  AC            0  Kasur
# 7               KMD  WiFi   0            0  Kasur
# 8               KMD  WiFi  AC            0  Kasur
# 9               KMD     0  AC            0  Kasur

# %%
data.dtypes
# Out:
# nama                 object
# harga                 int64
# rating               object
# jenis                object
# Kamar Mandi Dalam    object
# Wifi                 object
# AC                   object
# Kloset Duduk         object
# Kasur                object
# dtype: object

# %%
data.columns
# Out:
# Index(['nama', 'harga', 'rating', 'jenis', 'Kamar Mandi Dalam', 'Wifi', 'AC',
#        'Kloset Duduk', 'Kasur'],
#       dtype='object')

# %%
data=data.rename(columns = {"Kamar Mandi Dalam": "Kamar_Mandi_Dalam", "Kloset Duduk": "Kloset_Duduk"})

# %%
data = data[data.duplicated()]
print(data.shape)
# Out:
# (9089, 9)

# %%
data.drop_duplicates()
# Out:
#                                                     nama    harga rating  \
# 20           Kost Apik Aisyah Kukusan Tipe A  Beji Depok  1143000      0
# 21       Kost Apik UI Puspita  Tipe A Kukusan Beji Depok  1323000      0
# 22     Kost Singgahsini Alhidayah EMH-4 Tipe A  Beji ...  1683000      0
# 25       Kost Apik Duta Residence Tipe B Sukmajaya Depok  1008000   50.0
# 27                Kost Apik Wisma Okki Tipe B Beji Depok  1008000   47.0
# ...                                                  ...      ...    ...
# 10930                Kost Samitra Tipe A Cimanggis Depok  1350000      0
# 10932                 Kost Rumah Samara Kelapa Dua Depok  1350000   50.0
# 10955                Kost Kosisti Pondok Cina Beji Depok   700000   44.0
# 10967  Kost Singgahsini Alhidayah EMH-4 Tipe A  Beji ...  1683000   50.0
# 10982            Kost Permata Sukses 2 Tipe B Beji Depok  1800000   31.0
#
#         jenis Kamar_Mandi_Dalam  Wifi  AC Kloset_Duduk  Kasur
# 20      Putri               KMD     0  AC            0  Kasur
# 21      Putri               KMD  WiFi  AC            0  Kasur
# 22      Putri               KMD  WiFi  AC           KD  Kasur
# 25     Campur               KMD  WiFi   0            0  Kasur
# 27      Putri               KMD  WiFi   0            0  Kasur
# ...       ...               ...   ...  ..          ...    ...
# 10930   Putra               KMD  WiFi  AC            0  Kasur
# 10932   Putra               KMD  WiFi   0           KD  Kasur
# 10955   Putri               KMD  WiFi   0            0  Kasur
# 10967   Putri               KMD  WiFi  AC           KD  Kasur
# 10982   Putri               KMD  WiFi  AC           KD  Kasur
#
# [1071 rows x 9 columns]

# %%
data.shape
# Out:
# (9089, 9)

# %%
data.drop('nama', axis=1, inplace=True)
data.drop('rating',axis=1,inplace=True)

# %%
data.head()
# Out:
#       harga   jenis Kamar_Mandi_Dalam  Wifi  AC Kloset_Duduk  Kasur
# 20  1143000   Putri               KMD     0  AC            0  Kasur
# 21  1323000   Putri               KMD  WiFi  AC            0  Kasur
# 22  1683000   Putri               KMD  WiFi  AC           KD  Kasur
# 25  1008000  Campur               KMD  WiFi   0            0  Kasur
# 27  1008000   Putri               KMD  WiFi   0            0  Kasur

# %%
data.jenis.value_counts()
# Out:
# jenis
# Putri     4425
# Campur    2797
# Putra     1867
# Name: count, dtype: int64

# %%
data.Kamar_Mandi_Dalam.value_counts()
# Out:
# Kamar_Mandi_Dalam
# KMD    8278
# 0       811
# Name: count, dtype: int64

# %%
data.Wifi.value_counts()
# Out:
# Wifi
# WiFi    6813
# 0       2276
# Name: count, dtype: int64

# %%
data.AC.value_counts()
# Out:
# AC
# AC    4952
# 0     4137
# Name: count, dtype: int64

# %%
data.Kloset_Duduk.value_counts()
# Out:
# Kloset_Duduk
# KD    6124
# 0     2965
# Name: count, dtype: int64

# %%
data.Kasur.value_counts()
# Out:
# Kasur
# Kasur    8851
# 0         238
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9089 entries, 20 to 10999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   harga              9089 non-null   int64
#  1   jenis              9089 non-null   object
#  2   Kamar_Mandi_Dalam  9089 non-null   object
#  3   Wifi               9089 non-null   object
#  4   AC                 9089 non-null   object
#  5   Kloset_Duduk       9089 non-null   object
#  6   Kasur              9089 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 568.1+ KB

# %%
from pandas import DataFrame

# %%
def preprocess_data(
    df: DataFrame,
    one_hot_cols: [str],
    standardized_cols: [str],
    scaler: StandardScaler,

):
  result_df = df.copy()
  result_df = encode_multivalued_attributes_with_one_hot_encoding(result_df, one_hot_cols)
  result_df, _ = standardize_attributes(result_df, standardized_cols, scaler)
  return result_df

# %%
s = (data.dtypes == 'object')
object_cols = list(s[s].index)
one_hot_cols = (list(set(object_cols)))

# %%
object_cols = list(s[s].index)
object_cols
# Out:
# ['jenis', 'Kamar_Mandi_Dalam', 'Wifi', 'AC', 'Kloset_Duduk', 'Kasur']

# %%
def encode_multivalued_attributes_with_one_hot_encoding(
    df: DataFrame, col_names: [str]
):
  result_df = df.copy()
  for col_name in col_names:
    one_hot_values_df = pd.get_dummies(result_df[col_name], prefix=col_name, drop_first=True)
    result_df = pd.concat([result_df, one_hot_values_df], axis=1)
    result_df = result_df.drop(col_name, axis=1)

  return result_df

# %%
one_hot_cols
# Out:
# ['Kasur', 'Kamar_Mandi_Dalam', 'jenis', 'AC', 'Wifi', 'Kloset_Duduk']

# %%
data_preProcess=encode_multivalued_attributes_with_one_hot_encoding(data, one_hot_cols)

# %%
data_preProcess.head(5)
# Out:
#       harga  Kasur_Kasur  Kamar_Mandi_Dalam_KMD  jenis_Putra  jenis_Putri  \
# 20  1143000         True                   True        False         True
# 21  1323000         True                   True        False         True
# 22  1683000         True                   True        False         True
# 25  1008000         True                   True        False        False
# 27  1008000         True                   True        False         True
#
#     AC_AC  Wifi_WiFi  Kloset_Duduk_KD
# 20   True      False            False
# 21   True       True            False
# 22   True       True             True
# 25  False       True            False
# 27  False       True            False

# %%
data_preProcess.tail(5)
# Out:
#          harga  Kasur_Kasur  Kamar_Mandi_Dalam_KMD  jenis_Putra  jenis_Putri  \
# 10995   700000         True                  False         True        False
# 10996   900000         True                  False         True        False
# 10997   800000        False                   True        False         True
# 10998  2499000         True                   True        False        False
# 10999  1100000        False                   True        False        False
#
#        AC_AC  Wifi_WiFi  Kloset_Duduk_KD
# 10995  False       True             True
# 10996  False       True            False
# 10997  False       True            False
# 10998   True       True             True
# 10999   True      False             True

# %%
data.harga.describe()
# Out:
# count    9.089000e+03
# mean     1.271204e+06
# std      5.163714e+05
# min      3.500000e+05
# 25%      8.500000e+05
# 50%      1.233000e+06
# 75%      1.548000e+06
# max      3.035000e+06
# Name: harga, dtype: float64

# %%
def standardize_attributes(df: DataFrame, col_names: [str], scaler: StandardScaler = None):
  result_df = df.copy()

  if not scaler:
    scaler = StandardScaler()
    scaler.fit(result_df[col_names])

  result_df[col_names] = scaler.transform(result_df[col_names])

  return result_df, scaler

# %%
numeric_cols=(list(set(data) - set(object_cols)))

# %%
numeric_cols
# Out:
# ['harga']

# %%
standardized_cols = numeric_cols

# %%
standardized_cols
# Out:
# ['harga']

# %%
data_preProcess=standardize_attributes(data_preProcess, standardized_cols)

# %%
data_preProcess
# Out:
# (          harga  Kasur_Kasur  Kamar_Mandi_Dalam_KMD  jenis_Putra  jenis_Putri  \
#  20    -0.248292         True                   True        False         True
#  21     0.100314         True                   True        False         True
#  22     0.797525         True                   True        False         True
#  25    -0.509746         True                   True        False        False
#  27    -0.509746         True                   True        False         True
#  ...         ...          ...                    ...          ...          ...
#  10995 -1.106248         True                  False         True        False
#  10996 -0.718909         True                  False         True        False
#  10997 -0.912579        False                   True        False         True
#  10998  2.377870         True                   True        False        False
#  10999 -0.331570        False                   True        False        False
#
#         AC_AC  Wifi_WiFi  Kloset_Duduk_KD
#  20      True      False            False
#  21      True       True            False
#  22      True       True             True
#  25     False       True            False
#  27     False       True            False
#  ...      ...        ...              ...
#  10995  False       True             True
#  10996  False       True            False
#  10997  False       True            False
#  10998   True       True             True
#  10999   True      False             True
#
#  [9089 rows x 8 columns],
#  StandardScaler())

# %%
prep_data, new_scaler = standardize_attributes(data, standardized_cols)
new_scaler
# Out:
# StandardScaler()

# %%
prep_data = preprocess_data(data, one_hot_cols, standardized_cols, new_scaler)   # Hasil Preprocessing: prep_data
prep_data.shape
# Out:
# (9089, 8)

# %%
prep_data.head()
# Out:
#        harga  Kasur_Kasur  Kamar_Mandi_Dalam_KMD  jenis_Putra  jenis_Putri  \
# 20 -0.248292         True                   True        False         True
# 21  0.100314         True                   True        False         True
# 22  0.797525         True                   True        False         True
# 25 -0.509746         True                   True        False        False
# 27 -0.509746         True                   True        False         True
#
#     AC_AC  Wifi_WiFi  Kloset_Duduk_KD
# 20   True      False            False
# 21   True       True            False
# 22   True       True             True
# 25  False       True            False
# 27  False       True            False

# %%
prep_data.describe()
# Out:
#               harga
# count  9.089000e+03
# mean   1.430623e-16
# std    1.000055e+00
# min   -1.784093e+00
# 25%   -8.157439e-01
# 50%   -7.398883e-02
# 75%    5.360708e-01
# max    3.415940e+00

# %%
plt.boxplot(prep_data.harga)
plt.plot()
# Out:
# []

# %%
# Menghitung kuartil pertama (Q1) dan kuartil ketiga (Q3)
Q1 = prep_data[['harga']].quantile(0.25)
Q3 = prep_data[['harga']].quantile(0.75)

# Menghitung Interquartile Range (IQR)
IQR = Q3 - Q1

# Menghitung nilai maksimum dan minimum untuk menentukan batas outlier
maximum = Q3 + (1.5 * IQR)
minimum = Q1 - (1.5 * IQR)

print('Nilai Maximum dari kolom "harga" adalah:')
print(maximum)

print('\nNilai Minimum dari kolom "harga" adalah:')
print(minimum)

# Mengidentifikasi data yang melebihi batas outlier
more_than = prep_data[['harga']] > maximum
lower_than = prep_data[['harga']] < minimum

# Menangani outlier dengan menetapkan nilai maksimum dan minimum yang dihitung
prep_data.loc[more_than['harga'], 'harga'] = maximum.iloc[0]
prep_data.loc[lower_than['harga'], 'harga'] = minimum.iloc[0]

print('\nPersebaran data setelah ditangani Outlier:')
print(prep_data[['harga']].describe())
# Out:
# Nilai Maximum dari kolom "harga" adalah:
# harga    2.563793
# dtype: float64
#
# Nilai Minimum dari kolom "harga" adalah:
# harga   -2.843466
# dtype: float64
#
# Persebaran data setelah ditangani Outlier:
#              harga
# count  9089.000000
# mean     -0.010220
# std       0.969182
# min      -1.784093
# 25%      -0.815744
# 50%      -0.073989
# 75%       0.536071
# max       2.563793

# %%
prep_data.shape
# Out:
# (9089, 8)

# %%
plt.figure (figsize=(10,8))
sns.heatmap(prep_data.corr(), annot=True, linewidth=.5, cmap= "RdBu")
plt.title("Correlations Between Variables", size=10)
plt.show()

# %%
numeric_cols = prep_data.select_dtypes(include = [np.number])
corr = numeric_cols.corr()
print ('The Most Correlated Features with Harga:'), print (corr['harga'].sort_values(ascending = False)[:10], '\n')
print ('The Most Uncorrelated Features with Harga:'), print (corr['harga'].sort_values(ascending = False)[-5:])
# Out:
# The Most Correlated Features with Harga:
# harga    1.0
# Name: harga, dtype: float64
#
# The Most Uncorrelated Features with Harga:
# harga    1.0
# Name: harga, dtype: float64
# (None, None)

# %%
prep_data[['harga']].describe()
# Out:
#              harga
# count  9089.000000
# mean     -0.010220
# std       0.969182
# min      -1.784093
# 25%      -0.815744
# 50%      -0.073989
# 75%       0.536071
# max       2.563793

# %%
#mengimplementasikan train/test
from sklearn.model_selection import train_test_split

# %%
X = prep_data.drop(['harga'], axis = 1)
y = prep_data['harga']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# untuk mengatasi pengulangan proses hasil running yang berubah-ubah
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

# %%
print(X_train)
# Out:
#        Kasur_Kasur  Kamar_Mandi_Dalam_KMD  jenis_Putra  jenis_Putri  AC_AC  \
# 10862         True                  False        False        False   True
# 1042         False                   True        False         True  False
# 6927          True                   True         True        False   True
# 9695          True                   True        False         True  False
# 7574          True                   True         True        False   True
# ...            ...                    ...          ...          ...    ...
# 3297          True                   True        False        False  False
# 10874         True                   True        False         True   True
# 7799          True                   True        False        False   True
# 2084          True                   True        False        False   True
# 7307          True                   True         True        False  False
#
#        Wifi_WiFi  Kloset_Duduk_KD
# 10862       True            False
# 1042       False            False
# 6927        True             True
# 9695        True            False
# 7574        True             True
# ...          ...              ...
# 3297        True            False
# 10874       True             True
# 7799        True             True
# 2084        True             True
# 7307        True            False
#
# [7271 rows x 7 columns]

# %%
print(X_test)
# Out:
#       Kasur_Kasur  Kamar_Mandi_Dalam_KMD  jenis_Putra  jenis_Putri  AC_AC  \
# 2679         True                   True        False        False   True
# 4623         True                   True        False         True   True
# 2180         True                   True        False        False  False
# 9865         True                   True        False         True  False
# 9507         True                  False        False         True   True
# ...           ...                    ...          ...          ...    ...
# 8215         True                   True        False         True   True
# 7709         True                   True        False         True   True
# 9415        False                   True        False        False  False
# 4128         True                   True         True        False   True
# 1882         True                   True        False         True   True
#
#       Wifi_WiFi  Kloset_Duduk_KD
# 2679      False             True
# 4623       True             True
# 2180      False             True
# 9865       True            False
# 9507       True             True
# ...         ...              ...
# 8215       True             True
# 7709       True             True
# 9415      False            False
# 4128      False            False
# 1882       True             True
#
# [1818 rows x 7 columns]

# %%
scaler= StandardScaler()
scaler.fit(X_train)
X_train_scaled= scaler.transform(X_train)
X_test_scaled= scaler.transform(X_test)

# %%
from sklearn import metrics
from sklearn.metrics import r2_score

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_reg_model= LinearRegression()
linear_reg_model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred = linear_reg_model.predict(X_test_scaled)
y_pred = pd.DataFrame(y_pred)
MAE_li_reg= metrics.mean_absolute_error(y_test, y_pred)
MSE_li_reg = metrics.mean_squared_error(y_test, y_pred)
RMSE_li_reg =np.sqrt(MSE_li_reg)
pd.DataFrame([MAE_li_reg, MSE_li_reg, RMSE_li_reg], index=['MAE_li_reg', 'MSE_li_reg', 'RMSE_li_reg'], columns=['Metrics'])
# Out:
#               Metrics
# MAE_li_reg   0.448707
# MSE_li_reg   0.358609
# RMSE_li_reg  0.598840

# %%
scores = cross_val_score(linear_reg_model, X_train_scaled, y_train, cv=5)
print(np.sqrt(scores))
# Out:
# [0.78967314 0.78076477 0.76723718 0.79043483 0.77016271]

# %%
r2_score(y_test, linear_reg_model.predict(X_test_scaled))
# Out:
# 0.6187387911371013

# %% [markdown]
# ## Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree_reg_model =DecisionTreeRegressor()
tree_reg_model.fit(X_train_scaled, y_train);

# %%
y_pred = tree_reg_model.predict(X_test_scaled)
y_pred = pd.DataFrame(y_pred)
MAE_tree_reg= metrics.mean_absolute_error(y_test, y_pred)
MSE_tree_reg = metrics.mean_squared_error(y_test, y_pred)
RMSE_tree_reg =np.sqrt(MSE_tree_reg)
pd.DataFrame([MAE_tree_reg, MSE_tree_reg, RMSE_tree_reg],
    index=['MAE_tree_reg', 'MSE_tree_reg', 'RMSE_tree_reg'], columns=['Metrics'])
# Out:
#                 Metrics
# MAE_tree_reg   0.400611
# MSE_tree_reg   0.292727
# RMSE_tree_reg  0.541043

# %%
scores = cross_val_score(tree_reg_model, X_train_scaled, y_train, cv=5)
print(np.sqrt(scores))
# Out:
# [0.82289144 0.82348561 0.80689687 0.83132465 0.81310803]

# %%
r2_score(y_test, tree_reg_model.predict(X_test_scaled))
# Out:
# 0.6887819191552271

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
forest_reg_model =RandomForestRegressor()
forest_reg_model.fit(X_train_scaled, y_train);

# %%
y_pred = forest_reg_model.predict(X_test_scaled)
y_pred = pd.DataFrame(y_pred)
MAE_forest_reg= metrics.mean_absolute_error(y_test, y_pred)
MSE_forest_reg = metrics.mean_squared_error(y_test, y_pred)
RMSE_forest_reg =np.sqrt(MSE_forest_reg)
pd.DataFrame([MAE_forest_reg, MSE_forest_reg, RMSE_forest_reg],
    index=['MAE_forest_reg', 'MSE_forest_reg', 'RMSE_forest_reg'], columns=['Metrics'])
# Out:
#                   Metrics
# MAE_forest_reg   0.401076
# MSE_forest_reg   0.292981
# RMSE_forest_reg  0.541277

# %%
scores = cross_val_score(forest_reg_model, X_train_scaled, y_train, cv=5)
print(np.sqrt(scores))
# Out:
# [0.82282958 0.82350391 0.80690899 0.83124412 0.81308315]

# %%
r2_score(y_test, forest_reg_model.predict(X_test_scaled))
# Out:
# 0.6885121991110146
